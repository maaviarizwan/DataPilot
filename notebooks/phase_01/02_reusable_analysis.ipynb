# %%
import sys
from pathlib import Path
import pandas as pd

# %%
PROJECT_ROOT = Path.cwd()

if PROJECT_ROOT.name == "phase_01":
    PROJECT_ROOT = PROJECT_ROOT.parent.parent

sys.path.append(str(PROJECT_ROOT))

print(PROJECT_ROOT)
# Out:
# d:\VS Code\DataPilot

# %%
from src.cleaning.data_cleaner import prepare_dataset

from src.analysis.sales_analysis import (
    total_sales,
    sales_by_region,
    sales_by_category,
    yearly_growth,
    region_summary,
    top_products
)

from src.analysis.shipping_analysis import (
    shipping_by_mode,
    shipping_range
)

# %%
from src.cleaning.data_cleaner import prepare_dataset

from src.analysis.sales_analysis import (
    total_sales,
    sales_by_region,
    sales_by_category,
    yearly_growth,
    region_summary,
    top_products
)

from src.analysis.shipping_analysis import (
    shipping_by_mode,
    shipping_range
)

# %%
DATA_PATH = PROJECT_ROOT / "data" / "raw" / "superstore.csv"

df = pd.read_csv(DATA_PATH)

df = prepare_dataset(df)
df.head()
# Out:
#    Row ID        Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2017-152156 2017-11-08 2017-11-11    Second Class    CG-12520
# 1       2  CA-2017-152156 2017-11-08 2017-11-11    Second Class    CG-12520
# 2       3  CA-2017-138688 2017-06-12 2017-06-16    Second Class    DV-13045
# 3       4  US-2016-108966 2016-10-11 2016-10-18  Standard Class    SO-20335
# 4       5  US-2016-108966 2016-10-11 2016-10-18  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City  ...  \
# 0      Claire Gute   Consumer  United States        Henderson  ...
# 1      Claire Gute   Consumer  United States        Henderson  ...
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  ...
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
#
#           Category  Sub-Category  \
# 0        Furniture     Bookcases
# 1        Furniture        Chairs
# ...

# %%
print(f"Total Sales: ${total_sales(df):,.2f}")
# Out:
# Total Sales: $2,261,536.78

# %%
sales_by_region(df)
# Out:
# Region
# West       710219.6845
# East       669518.7260
# Central    492646.9132
# South      389151.4590
# Name: Sales, dtype: float64

# %%
sales_by_category(df)
# Out:
# Category
# Technology         827455.8730
# Furniture          728658.5757
# Office Supplies    705422.3340
# Name: Sales, dtype: float64

# %%
yearly_growth(df)
# Out:
#                   Sales   Growth %
# Order Year
# 2015        479856.2081        NaN
# 2016        459436.0054  -4.255484
# 2017        600192.5500  30.636812
# 2018        722052.0192  20.303396

# %%
region_summary(df)
# Out:
#                Sales  Share %
# Region
# West     710219.6845    31.40
# East     669518.7260    29.60
# Central  492646.9132    21.78
# South    389151.4590    17.21

# %%
top_products(df, 10)
# Out:
# Product Name
# Canon imageCLASS 2200 Advanced Copier                                          61599.824
# Fellowes PB500 Electric Punch Plastic Comb Binding Machine with Manual Bind    27453.384
# Cisco TelePresence System EX90 Videoconferencing Unit                          22638.480
# HON 5400 Series Task Chairs for Big and Tall                                   21870.576
# GBC DocuBind TL300 Electric Binding System                                     19823.479
# GBC Ibimaster 500 Manual ProClick Binding System                               19024.500
# Hewlett Packard LaserJet 3310 Copier                                           18839.686
# HP Designjet T520 Inkjet Large Format Printer - 24" Color                      18374.895
# GBC DocuBind P400 Electric Binding System                                      17965.068
# High Speed Automatic Electric Letter Opener                                    17030.312
# Name: Sales, dtype: float64

# %%
top_products(df, 10)
# Out:
# Product Name
# Canon imageCLASS 2200 Advanced Copier                                          61599.824
# Fellowes PB500 Electric Punch Plastic Comb Binding Machine with Manual Bind    27453.384
# Cisco TelePresence System EX90 Videoconferencing Unit                          22638.480
# HON 5400 Series Task Chairs for Big and Tall                                   21870.576
# GBC DocuBind TL300 Electric Binding System                                     19823.479
# GBC Ibimaster 500 Manual ProClick Binding System                               19024.500
# Hewlett Packard LaserJet 3310 Copier                                           18839.686
# HP Designjet T520 Inkjet Large Format Printer - 24" Color                      18374.895
# GBC DocuBind P400 Electric Binding System                                      17965.068
# High Speed Automatic Electric Letter Opener                                    17030.312
# Name: Sales, dtype: float64

# %%
shipping_by_mode(df)
# Out:
# Ship Mode
# Same Day          0.044610
# First Class       2.179214
# Second Class      3.249211
# Standard Class    5.008363
# Name: Shipping Days, dtype: float64

# %%
shipping_range(df)
# Out:
# {'minimum_days': np.int64(0),
#  'maximum_days': np.int64(7),
#  'negative_records': 0}

# %%
from src.analysis.data_profiler import (
    profile_dataset,
    numeric_summary,
    missing_value_summary
    
)

# %%
profile = profile_dataset(df)

profile
# Out:
# {'rows': 9800,
#  'columns': 24,
#  'column_names': ['Row ID',
#   'Order ID',
#   'Order Date',
#   'Ship Date',
#   'Ship Mode',
#   'Customer ID',
#   'Customer Name',
#   'Segment',
#   'Country',
#   'City',
#   'State',
#   'Postal Code',
#   'Region',
#   'Product ID',
#   'Category',
#   'Sub-Category',
#   'Product Name',
#   'Sales',
#   'Order Year',
#   'Order Month',
#   'Order Month Name',
#   'Order Quarter',
#   'Order Day',
#   'Shipping Days'],
#  'duplicate_rows': 0,
#  'missing_values': {'Row ID': 0,
#   'Order ID': 0,
#   'Order Date': 0,
#   'Ship Date': 0,
#   'Ship Mode': 0,
#   'Customer ID': 0,
#   'Customer Name': 0,
#   'Segment': 0,
#   'Country': 0,
#   'City': 0,
#   'State': 0,
#   'Postal Code': 11,
#   'Region': 0,
#   'Product ID': 0,
#   'Category': 0,
#   'Sub-Category': 0,
#   'Product Name': 0,
#   'Sales': 0,
#   'Order Year': 0,
#   'Order Month': 0,
#   'Order Month Name': 0,
#   'Order Quarter': 0,
#   'Order Day': 0,
# ...

# %%
numeric_summary(df)
# Out:
#             Row ID                  Order Date                   Ship Date  \
# count  9800.000000                        9800                        9800
# mean   4900.500000  2017-05-01 05:13:51.673469  2017-05-05 04:17:52.653061
# min       1.000000         2015-01-03 00:00:00         2015-01-07 00:00:00
# 25%    2450.750000         2016-05-24 00:00:00         2016-05-27 18:00:00
# 50%    4900.500000         2017-06-26 00:00:00         2017-06-29 00:00:00
# 75%    7350.250000         2018-05-15 00:00:00         2018-05-19 00:00:00
# max    9800.000000         2018-12-30 00:00:00         2019-01-05 00:00:00
# std    2829.160653                         NaN                         NaN
#
#         Postal Code         Sales   Order Year  Order Month  Order Quarter  \
# count        9789.0   9800.000000  9800.000000  9800.000000    9800.000000
# mean   55273.322403    230.769059  2016.724184     7.818469       2.885816
# ...

# %%
missing_value_summary(df)
# Out:
#              Missing Count  Missing %
# Postal Code             11       0.11

# %%
from src.analysis.data_profiler import dataset_overview

# %%
dataset_overview(df)
# Out:
# ...
# DATASET OVERVIEW
# ...
# Rows: 9800
# Columns: 24
# Duplicate Rows: 0
#
# Numeric Columns:
#  - Row ID
#  - Postal Code
#  - Sales
#  - Order Year
#  - Order Month
#  - Order Quarter
#  - Order Day
#  - Shipping Days
#
# Categorical Columns:
#  - Order ID
#  - Ship Mode
#  - Customer ID
#  - Customer Name
#  - Segment
#  - Country
#  - City
#  - State
#  - Region
#  - Product ID
#  - Category
#  - Sub-Category
#  - Product Name
#  - Order Month Name
#
# Datetime Columns:
#  - Order Date
#  - Ship Date
#
# Missing Values:
#  - Postal Code: 11
